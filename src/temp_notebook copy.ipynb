# %%
from highlight_utils import create_highlight_clip

# Set team names
non_bibs_team_name = "Non-bibs FC" # Non-bibs FC
bibs_team_name = "Bibs FC" # Bibs FC
team_n = ["Alex","Yaw", "Ben", "José","Jeezy", "Kostas", "David"]
team_b = ["Gerald", "Kevin", "Nik","Yi", "Henry", "George", "Theo"]


non_bibs_team = {
    "name": non_bibs_team_name,
    "players": team_n,
    "captain": team_n[0]  # Assuming the first player is the captain
}

bibs_team = {
    "name": bibs_team_name,
    "players": team_b,
    "captain": team_b[0]  # Assuming the first player is the captain
}

gopro={"time":4.18, "path":"Game 1 Left.mp4","overlap_px":200}#left
highlights2 = [
    {"time": 4.18, "text": "Kick-off","angle":2},
    {"time":3.55, "team":"n", "scored":"Kostas", "assist":"Ben","angle":2},
]



create_highlight_clip("Game 1 Right.mp4",highlights2,non_bibs_team, bibs_team,cam2=gopro)
# Out:
# Moviepy - Building video Game 1 Right Highlights - 2025-12-26_v4.mp4.
# MoviePy - Writing audio in Game 1 Right Highlights - 2025-12-26_v4TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video Game 1 Right Highlights - 2025-12-26_v4.mp4
# t:  43%|████▎     | 643/1500 [09:28<16:27,  1.15s/it, now=None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 30
#      22 gopro={"time":4.18, "path":"Game 1 Left.mp4","overlap_px":200}#left
#      23 highlights2 = [
#      24     {"time": 4.18, "text": "Kick-off","angle":2},
#      25     {"time":3.55, "team":"n", "scored":"Kostas", "assist":"Ben","angle":2},
#      26 ]
# ---> 30 create_highlight_clip("Game 1 Right.mp4",highlights2,non_bibs_team, bibs_team,cam2=gopro)
#
# ...

# %%
2.52-2.503
# Out:
# 0.016999999999999904

# %%
from highlight_utils import create_highlight_clip

# Set team names
non_bibs_team_name = "Non-bibs FC" # Non-bibs FC
bibs_team_name = "Bibs FC" # Bibs FC
team_n = ["Alex","Yaw", "Ben", "José","Jeezy", "Kostas", "David"]
team_b = ["Gerald", "Kevin", "Nik","Yi", "Henry", "George", "Theo"]


non_bibs_team = {
    "name": non_bibs_team_name,
    "players": team_n,
    "captain": team_n[0]  # Assuming the first player is the captain
}

bibs_team = {
    "name": bibs_team_name,
    "players": team_b,
    "captain": team_b[0]  # Assuming the first player is the captain
}

gopro={"time":2.537, "path":"18th November game2 Left.mp4","overlap_px":220}#left
highlights2 = [
    {"time": 2.52, "text": "Kick-off","angle":2},
    {"time":3.55, "team":"n", "scored":"Kostas", "assist":"Ben","angle":2},
    {"time":7.18, "team":"n", "scored":"Ben", "assist":"Jeezy","angle":2},
    {"time": 7.46, "text": "Save","angle":2},
    {"time":10.19, "team":"n", "scored":"David", "assist":"Ben","angle":2},
    {"time": 12.53, "text": "Save","angle":2},
    {"time":15.49, "team":"b", "scored":"Gerald","angle":2},
    {"time":18.31, "team":"n", "scored":"Ben", "assist":"David","angle":2},
    {"time":19.51, "team":"b", "scored":"Henry", "assist":"Gerald","angle":2},# 21.00 criminal touch
    {"time":21.48, "team":"n", "scored":"Ben", "assist":"José","angle":2},
    {"time": 22.54, "text": "George","angle":2},
    {"time": 26.50, "text": "Save","angle":2},
    {"time":27.20, "team":"n", "scored":"Alex", "assist":"Kostas","angle":2},
    {"time": 28.54, "text": "Nearly","angle":2},
    {"time":29.05,"start":28.59, "team":"n", "scored":"Ben", "assist":"Alex","angle":2},
    {"time": 31.12, "text": "Save","angle":2},
    {"time":31.46, "team":"b", "scored":"Theo", "assist":"Kevin","angle":2},
    {"time":32.22, "team":"b", "scored":"Theo", "assist":"Gerald","angle":2},
    {"time": 34.00, "text": "Save","angle":2},
    {"time":35.00, "team":"n", "scored":"José", "assist":"Yaw","angle":2},
    {"time": 35.33, "text": "Save","angle":2},
    {"time":36.02, "team":"b", "scored":"Gerald", "assist":"Nik","angle":2},
    {"time":36.59, "team":"b", "scored":"Theo", "assist":"Gerald","angle":2},
    {"time":41.07, "team":"n", "scored":"Kostas", "assist":"Ben"},#check
    {"time": 41.22, "text": "Full Time"},
]



create_highlight_clip("18th November Game 2 Right.mp4",highlights2,non_bibs_team, bibs_team,game=2,cam2=gopro)
# Out:
# Moviepy - Building video 18th November Game 2 Right Highlights - 2025-11-21_v2.mp4.
# MoviePy - Writing audio in 18th November Game 2 Right Highlights - 2025-11-21_v2TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video 18th November Game 2 Right Highlights - 2025-11-21_v2.mp4
# Moviepy - Done !
# Moviepy - video ready 18th November Game 2 Right Highlights - 2025-11-21_v2.mp4

# %%
2299/60
# Out:
# 38.31666666666667

# %%
from highlight_utils import create_highlight_clip
from moviepy.editor import VideoFileClip, CompositeVideoClip, TextClip


# === Load your two camera feeds ===
video0 = VideoFileClip("Game 1 Left.mp4")#.subclip(20,30)  # Left side
video2 = VideoFileClip("Game 1 Right.mp4")#.subclip(20,30)#34.4)  # Right side

# === Define overlap in pixels (adjust based on your footage) ===
overlap_px = 200  # Try 80–150 depending on how much the cameras overlap

# === Crop each video to remove overlap ===
left_cropped = video0.crop(x2=video0.w - overlap_px)
right_cropped = video2.crop(x1=overlap_px)

# === Align right video next to left ===
right_positioned = right_cropped.set_position((left_cropped.w, 0))

# === Combine both into one stitched view ===
stitched_width = left_cropped.w + right_cropped.w
stitched_height = max(left_cropped.h, right_cropped.h)

stitched_clip = CompositeVideoClip(
    [left_cropped, right_positioned],
    size=(stitched_width, stitched_height)
)

# === Preview or export ===
#stitched_clip.preview()  # For notebook testing
stitched_clip.write_videofile("stitched_output.mp4", codec="libx264", fps=25)
# Out:
# Moviepy - Building video stitched_output.mp4.
# MoviePy - Writing audio in stitched_outputTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video stitched_output.mp4
# Moviepy - Done !
# Moviepy - video ready stitched_output.mp4

# %%
from highlight_utils import create_highlight_clip
from moviepy.editor import VideoFileClip, CompositeVideoClip, TextClip


# === Load your two camera feeds ===
video0 = VideoFileClip("18th November game2 Left.mp4").subclip(1.7)#,31.7)  # Left side
video2 = VideoFileClip("18th November Game 2 Right.mp4")#.subclip(20,30)  # Right side

# === Define overlap in pixels (adjust based on your footage) ===
overlap_px = 80  # Try 80–150 depending on how much the cameras overlap

# === Crop each video to remove overlap ===
left_cropped = video0.crop(x2=video0.w - overlap_px)
right_cropped = video2.crop(x1=overlap_px)

# === Align right video next to left ===
right_positioned = right_cropped.set_position((left_cropped.w, 0))

# === Combine both into one stitched view ===
stitched_width = left_cropped.w + right_cropped.w
stitched_height = max(left_cropped.h, right_cropped.h)

stitched_clip = CompositeVideoClip(
    [left_cropped, right_positioned],
    size=(stitched_width, stitched_height)
)

# === Preview or export ===
#stitched_clip.preview()  # For notebook testing
stitched_clip.write_videofile("stitched_outputcheck20.mp4", codec="libx264", fps=25)
# Out:
# Moviepy - Building video stitched_outputcheck2.mp4.
# MoviePy - Writing audio in stitched_outputcheck2TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video stitched_outputcheck2.mp4
# Moviepy - Done !
# Moviepy - video ready stitched_outputcheck2.mp4
