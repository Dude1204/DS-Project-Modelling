# %%
from highlight_utils import create_highlight_clip
from moviepy.editor import VideoFileClip, CompositeVideoClip, TextClip


# === Load your two camera feeds ===
video0 = VideoFileClip("Game 2 Left.mp4").subclip(500,510)  # Left side
video2 = VideoFileClip("Game 2 Right.mp4").subclip(500,510)#34.4)  # Right side

# === Define overlap in pixels (adjust based on your footage) ===
overlap_px = 130  # Try 80–150 depending on how much the cameras overlap

# === Crop each video to remove overlap ===
left_cropped = video0.crop(x2=video0.w - overlap_px)
right_cropped = video2.crop(x1=overlap_px)

# === Align right video next to left ===
right_positioned = right_cropped.set_position((left_cropped.w, 0))

# === Combine both into one stitched view ===
stitched_width = left_cropped.w + right_cropped.w
stitched_height = max(left_cropped.h, right_cropped.h)

stitched_clip = CompositeVideoClip(
    [left_cropped, right_positioned],
    size=(stitched_width, stitched_height)
)

# === Preview or export ===
#stitched_clip.preview()  # For notebook testing
stitched_clip.write_videofile("jj_Game_2_Full.mp4", codec="libx264", fps=25)
# Out:
# Moviepy - Building video jj_Game_2_Full.mp4.
# MoviePy - Writing audio in jj_Game_2_FullTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video jj_Game_2_Full.mp4
# Moviepy - Done !
# Moviepy - video ready jj_Game_2_Full.mp4

# %%
"José"

# %%
# Set team names
non_bibs_team_name = "Non-bibs FC" # Non-bibs FC
bibs_team_name = "Bibs FC" # Bibs FC
team_n = ["George","Aaron", "Kevin", "Alex","Jon","Henry", "Jason -> Nik"]
team_b = ["José","Yi", "Sam","Pavlos", "Azamat","Yaw", "JC"]

non_bibs_team = {
    "name": non_bibs_team_name,
    "players": team_n,
    "captain": team_n[0]  # Assuming the first player is the captain
}

bibs_team = {
    "name": bibs_team_name,
    "players": team_b,
    "captain": team_b[0]  # Assuming the first player is the captain
}

from highlight_utils import create_highlight_clip
cam2={"time":0.44, "path":"Game 2 Left.mp4","overlap_px":270}#left 4.348
highlights2 = [
    {"time": 0.44, "text": "Kick-off","angle":2},
    {"time": 14.44, "text": "Nearly","angle":2},
    {"time":18.40, "team":"n", "scored":"Jon", "assist":"Kevin","angle":2},
    {"time":23.54, "team":"b", "scored":"Pavlos", "assist":"José","angle":2},
    {"time": 26.36, "text": "Save","angle":2},
    {"time":27.52, "team":"n", "scored":"Kevin", "assist":"Alex","angle":2},#left cam dies
    {"time": 27.57,"start":27.57, "text": "Left camera dies after this","angle":2},
    #28.42,42.13,44.10
    #46.20 pav jose
    {"time": 46.20, "text": "Pavlos 46' (José)\nNon-bibs: 5  Bibs: 2","angle":0},
    {"time": 46.25,"start":46.25, "text": "Right camera dies after this","angle":0},
    {"time": 46.40, "text": "FINAL SCORE\nNon-bibs: 7  Bibs: 4","angle":0},
]

create_highlight_clip("Game 2 Right.mp4",highlights2,non_bibs_team, bibs_team,game=2,cam2=cam2)
# Out:
# Moviepy - Building video Game 2 Right Highlights - 2026-02-18_v2.mp4.
# MoviePy - Writing audio in Game 2 Right Highlights - 2026-02-18_v2TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video Game 2 Right Highlights - 2026-02-18_v2.mp4
# Moviepy - Done !
# Moviepy - video ready Game 2 Right Highlights - 2026-02-18_v2.mp4

# %%
#4.01
