# %%
# Set team names
non_bibs_team_name = "Non-bibs FC" # Non-bibs FC
bibs_team_name = "Bibs FC" # Bibs FC
team_n = ["Gerald","Ben","Stu", "Manzan","Mani","Nik"]
team_b = ["Jon","Yi","George","Sam", "Kevin","Pavlos"]

non_bibs_team = {
    "name": non_bibs_team_name,
    "players": team_n,
    "captain": team_n[0]  # Assuming the first player is the captain
}

bibs_team = {
    "name": bibs_team_name,
    "players": team_b,
    "captain": team_b[0]  # Assuming the first player is the captain
}

from highlight_utils import create_highlight_clip
replays={"time_h": 3.14, "path_h": "Game 2 Home.mp4", "time_a": 0.39, "path_a": "Game 2 Away.mp4"}
highlights2 = [
    {"time": 1.31, "text": "Kick-off"},
    {"time":2.02, "team":"n", "scored":"Mani", "assist":"Gerald","replay":"h"},#h
    #{"time": 2.37, "text": "Nearly"},#h
    {"time":3.26, "team":"b", "scored":"Sam", "assist":"George","replay":"a"},#a
    {"time":5.51, "team":"n", "scored":"Ben", "assist":"Stu","replay":"h"},#h
    {"time":7.21, "team":"n", "scored":"Ben", "assist":"Mani","replay":"h"},#h
    {"time":8.40, "team":"n", "scored":"Ben", "assist":"Stu","replay":"h"},#h
    {"time":10.55, "team":"b", "scored":"Pavlos", "assist":"Kevin","replay":"a"},#a
    {"time":12.10, "team":"n", "scored":"Gerald", "assist":"Manzan","replay":"h"},#h
    {"time":13.29, "team":"b", "scored":"Pavlos", "assist":"Kevin","replay":"a"},#a potential kevin goal
    {"time":14.21, "team":"b", "scored":"Jon", "assist":"Pavlos","replay":"a"},#a
    {"time":14.53, "team":"n", "scored":"Gerald", "assist":"Mani","replay":"h"},#h
    {"time":18.00, "team":"b", "scored":"Jon", "assist":"Kevin","replay":"a"},#a
    {"time":20.39, "team":"n", "scored":"Manzan", "assist":"Mani","replay":"h"},#h
    {"time":21.37, "team":"n", "scored":"Stu", "assist":"Mani","replay":"h"},#h
    {"time":22.03, "team":"b", "scored":"Kevin", "assist":"George","replay":"a"},#a
    {"time":24.33, "team":"b", "scored":"Kevin", "assist":"George","replay":"a"},#a
    {"time":26.38, "team":"n", "scored":"Gerald", "assist":"Mani","replay":"h"},#h
    {"time":27.07, "team":"b", "scored":"Yi", "assist":"Jon","replay":"a"},#a
    {"time":28.24, "team":"b", "scored":"Jon", "assist":"Sam","replay":"a"},#a
    {"time":30.05, "team":"n", "scored":"Stu", "assist":"Mani","replay":"h","time_adjustment": 15},#h
    {"time": 31.21, "text": "Nearly"},#h
    {"time": 31.26, "start": 31.26, "text": "Save"},#h
    {"time":32.20, "team":"b", "scored":"Pavlos", "assist":"George","replay":"a"},#a
    {"time":36.20, "team":"b", "scored":"Jon", "assist":"Kevin","replay":"a"},#a
    {"time":36.33, "start": 36.30, "team":"n", "scored":"Gerald", "assist":"Stu","replay":"h"},#h
    
    {"time": 39.07, "text": "Full Time"},
]

create_highlight_clip("Game 2.mp4",highlights2,non_bibs_team, bibs_team,game=2,replays=replays)
# Out:
# Moviepy - Building video Game 2 Highlights - 2026-04-15_v1.mp4.
# MoviePy - Writing audio in Game 2 Highlights - 2026-04-15_v1TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video Game 2 Highlights - 2026-04-15_v1.mp4
# Moviepy - Done !
# Moviepy - video ready Game 2 Highlights - 2026-04-15_v1.mp4

# %%
from highlight_utils import create_highlight_clip
from moviepy.editor import VideoFileClip, CompositeVideoClip, TextClip


# === Load your two camera feeds ===
video0 = VideoFileClip("Game 2 Left.mp4")#.subclip(500,510)  # Left side
video2 = VideoFileClip("Game 2 Right.mp4")#.subclip(500,510)#34.4)  # Right side

# === Define overlap in pixels (adjust based on your footage) ===
overlap_px = 0  # Try 80–150 depending on how much the cameras overlap

# === Crop each video to remove overlap ===
left_cropped = video0.crop(x2=video0.w - overlap_px)
right_cropped = video2.crop(x1=overlap_px)

# === Align right video next to left ===
right_positioned = right_cropped.set_position((left_cropped.w, 0))

# === Combine both into one stitched view ===
stitched_width = left_cropped.w + right_cropped.w
stitched_height = max(left_cropped.h, right_cropped.h)

stitched_clip = CompositeVideoClip(
    [left_cropped, right_positioned],
    size=(stitched_width, stitched_height)
)

# === Preview or export ===
#stitched_clip.preview()  # For notebook testing
stitched_clip.write_videofile("jjGame_2_Full.mp4", codec="libx264", fps=25)
# Out:
# Moviepy - Building video Game_2_Full.mp4.
# MoviePy - Writing audio in Game_2_FullTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video Game_2_Full.mp4
# Moviepy - Done !
# Moviepy - video ready Game_2_Full.mp4

# %%
"José"

# %%
# Set team names
non_bibs_team_name = "Non-bibs FC" # Non-bibs FC
bibs_team_name = "Bibs FC" # Bibs FC
team_n = [ "Yi", "George","Manzan", "David", "JC","Gerald", "Jason" ]
team_b = ["José","Stu","Huzzy","Alex", "Henry", "Nik", "Sam"]

non_bibs_team = {
    "name": non_bibs_team_name,
    "players": team_n,
    "captain": team_n[0]  # Assuming the first player is the captain
}

bibs_team = {
    "name": bibs_team_name,
    "players": team_b,
    "captain": team_b[0]  # Assuming the first player is the captain
}

from highlight_utils import create_highlight_clip
cam2={"time":3.37, "path":"Game 2 Left.mp4","overlap_px":260}#left 4.348
highlights2 = [
    {"time": 3.37, "text": "Kick-off","angle":2},
    {"time":5.03, "team":"b", "scored":"José", "assist":"Huzzy","angle":2},
    {"time":7.49, "team":"n", "scored":"Jason", "assist":"Gerald","angle":2},
    {"time": 8.33, "text": "Nearly","angle":0},
    {"time":11.50, "team":"b", "scored":"José", "assist":"Henry","angle":2},#15.26 JC injury
    {"time":17.05, "team":"n", "scored":"Gerald", "assist":"Manzan","angle":0},
    {"time":18.30, "team":"n", "scored":"David", "assist":"Manzan","angle":0},
    {"time":19.40, "team":"b", "scored":"Huzzy", "assist":"Sam","angle":1},
    {"time":22.59, "team":"n", "scored":"Manzan","angle":0},
    {"time":26.34, "team":"b", "scored":"Huzzy", "assist":"Stu","angle":2},#check
    {"time":30.42, "team":"b", "scored":"Huzzy", "assist":"Stu","angle":2},
    {"time":32.40, "team":"n", "scored":"Manzan", "assist":"George","angle":0},
    {"time":34.06, "team":"b", "scored":"Stu", "assist":"Nik","angle":2},
    {"time":35.08, "team":"b", "scored":"Huzzy","angle":2},
    {"time":38.10, "team":"b", "scored":"Sam", "assist":"Stu","angle":2},
    {"time": 38.15, "start":38.15, "end":38.22, "text": "Full Time","angle":2},
]

create_highlight_clip("Game 2 Right.mp4",highlights2,non_bibs_team, bibs_team,game=2,cam2=cam2)
# Out:
# Moviepy - Building video Game 2 Right Highlights - 2026-03-27_v1.mp4.
# MoviePy - Writing audio in Game 2 Right Highlights - 2026-03-27_v1TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video Game 2 Right Highlights - 2026-03-27_v1.mp4
# Moviepy - Done !
# Moviepy - video ready Game 2 Right Highlights - 2026-03-27_v1.mp4
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print("Pavlos 46' (José)\nNon-bibs: 5  Bibs: 2")
# Out:
# Pavlos 46' (José)
# Non-bibs: 5  Bibs: 2

# %%
gol = "Non-bibs FC: 5\nJon 18' (Kevin)\nKevin 27' (Alex)\nUnrecorded * 3\n\nBibs FC: 2\nPavlos 23' (José)\n>>> Pavlos 46' (José)"
print("Non-bibs FC: 5\nJon 18' (Kevin)\nKevin 27' (Alex)\nUnrecorded * 3\n\nBibs FC: 2\nPavlos 23' (José)\n>>> Pavlos 46' (José)")
# Out:
# Non-bibs FC: 5
# Jon 18' (Kevin)
# Kevin 27' (Alex)
# Unrecorded * 3
#
# Bibs FC: 2
# Pavlos 23' (José)
# >>> Pavlos 46' (José)
