# %%
from highlight_utils import create_highlight_clip

# Set team names
non_bibs_team_name = "Non-bibs FC" # Non-bibs FC
bibs_team_name = "Bibs FC" # Bibs FC
team_n = ["Ben","George","Stu","Theo", "Yi","Alex", "Philippe"]
team_b = ["Henry","Gerald","Manzan", "Darroch","José","Jon", "Sam"]


non_bibs_team = {
    "name": non_bibs_team_name,
    "players": team_n,
    "captain": team_n[0]  # Assuming the first player is the captain
}

bibs_team = {
    "name": bibs_team_name,
    "players": team_b,
    "captain": team_b[0]  # Assuming the first player is the captain
}


highlights1 = [
    {"time": 2.17, "text": "Kick-off"},
    {"time": 4.00, "text": "Save"},
    {"time":5.01, "team":"n", "scored":"Stu", "assist":"George"},#better angle
    {"time":5.47, "team":"b", "scored":"Jon", "assist":"Manzan"},
    {"time":8.10, "team":"n", "scored":"Yi", "assist":"Philippe"},#better angle#8.50 camere hit
    {"time": 11.05, "text": "Nearly"},
    {"time":12.03, "team":"b", "scored":"Manzan", "assist":"Sam"},
    {"time": 12.48, "text": "Nearly"},#no goal
    {"time": 15.10, "text": "Save"},
    {"time":18.32, "team":"b", "scored":"José", "assist":"Sam"},
    {"time":19.24, "team":"b", "scored":"Manzan", "assist":"Darroch"},
    {"time":19.59, "team":"n", "scored":"Ben", "assist":"Stu"},
    {"time": 20.37, "text": "Nearly"},
    {"time":22.35, "team":"n", "scored":"Philippe", "assist":"Alex"},
    {"time": 23.19, "text": "Save"},
    {"time": 26.30, "text": "Nearly"},
    {"time": 27.16, "text": "Save"},
    {"time":27.45, "team":"n", "scored":"Ben", "assist":"George"},
    {"time":30.24, "team":"n", "scored":"Philippe", "assist":"George"},
    {"time": 31.44, "text": "Save"},
    {"time":34.47, "team":"b", "scored":"Jon", "assist":"Darroch"},
    {"time": 36.54, "text": "Save"},
    {"time": 37.49, "text": "Penalty"},
    {"time":39.08, "team":"b", "scored":"Gerald"},
    {"time": 39.23, "text": "Full Time"},
]

#44.49

create_highlight_clip("Game 1.mp4",highlights1,non_bibs_team, bibs_team)#,cam2=gopro)

# %%
from highlight_utils import create_highlight_clip
from moviepy.editor import VideoFileClip, CompositeVideoClip, TextClip


# === Load your two camera feeds ===
video0 = VideoFileClip("Game 1 Left.mp4")#.subclip(800,810)  # Left side
video2 = VideoFileClip("Game 1 Right.mp4")#.subclip(800,810)#34.4)  # Right side

# === Define overlap in pixels (adjust based on your footage) ===
overlap_px = 0  # Try 80–150 depending on how much the cameras overlap

# === Crop each video to remove overlap ===
left_cropped = video0.crop(x2=video0.w - overlap_px)
right_cropped = video2.crop(x1=overlap_px)

# === Align right video next to left ===
right_positioned = right_cropped.set_position((left_cropped.w, 0))

# === Combine both into one stitched view ===
stitched_width = left_cropped.w + right_cropped.w
stitched_height = max(left_cropped.h, right_cropped.h)

stitched_clip = CompositeVideoClip(
    [left_cropped, right_positioned],
    size=(stitched_width, stitched_height)
)

# === Preview or export ===
#stitched_clip.preview()  # For notebook testing
stitched_clip.write_videofile("jjGame_1_Full.mp4", codec="libx264", fps=25)
# Out:
# Moviepy - Building video Game_1_Full.mp4.
# MoviePy - Writing audio in Game_1_FullTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video Game_1_Full.mp4
# Moviepy - Done !
# Moviepy - video ready Game_1_Full.mp4

# %%
    # {"time": 31.16, "text": "Handball","angle":2},
    # {"start": 31.14,"time": 31.14,"end":31.18, "text": "Necessary?","angle":1, "slow":[[0.4,0.5],0.25,4.0]},
    # {"time":31.50, "team":"n", "scored":"Nik","angle":2},
    # {"time":32.56, "team":"b", "scored":"Ben", "assist":"Fillipos","angle":2},
    # {"time":35.10, "team":"b", "scored":"Fillipos", "assist":"Manzan","angle":2},
    # {"time": 37.12, "end":37.23, "text": "Save","angle":2},
    # {"time": 38.38, "text": "Full Time", "angle":2},

# %%
from highlight_utils import create_highlight_clip

# Set team names
non_bibs_team_name = "Non-bibs FC" # Non-bibs FC
bibs_team_name = "Bibs FC" # Bibs FC
team_n = ["Ben","George","Stu","Theo", "Yi","Alex", "Philippe"]
team_b = ["Henry","Gerald","Manzan", "Darroch","José","Jon", "Sam"]


non_bibs_team = {
    "name": non_bibs_team_name,
    "players": team_n,
    "captain": team_n[0]  # Assuming the first player is the captain
}

bibs_team = {
    "name": bibs_team_name,
    "players": team_b,
    "captain": team_b[0]  # Assuming the first player is the captain
}

gopro={"time":2.51, "path":"Game 1 Left.mp4","overlap_px":0}#left
highlights1 = [
    {"time": 2.51, "text": "Kick-off","angle":2},
    {"time":3.30, "team":"b", "scored":"David", "assist":"Gerald","angle":1},
    {"time": 4.00, "text": "Good Play","angle":2},
    {"time":4.37, "team":"n", "scored":"Stu", "assist":"Jeezy","angle":0},
    {"time":5.23, "team":"b", "scored":"David","angle":1},
    {"time":7.03, "team":"b", "scored":"George", "assist":"Gerald","angle":1},
    {"time": 9.24, "text": "Save","angle":2},
    {"time":9.46, "team":"n", "scored":"Alex", "assist":"JC","angle":0},
    {"time":10.44, "team":"n", "scored":"Yi", "assist":"Sam","angle":0},
    {"time": 14.47, "text": "Nearly","angle":2},
    {"time":15.40, "team":"b", "scored":"David","angle":1},
    {"time":16.28, "team":"b", "scored":"Manzan", "assist":"George","angle":2},
    {"time": 17.42, "text": "Save","angle":2},
    {"time":18.16, "team":"b", "scored":"Gerald", "assist":"David","angle":1},
    {"time":20.00, "team":"n", "scored":"Sam", "assist":"Jason","angle":2},
    {"time":21.40, "team":"b", "scored":"Gerald","angle":1},
    {"time":22.11, "team":"n", "scored":"Yi", "assist":"JC","angle":2},
    {"time":25.58, "team":"n", "scored":"Alex", "assist":"Stu","angle":2},
    {"time": 28.22, "text": "Nearly","angle":2},
    {"time": 29.20, "text": "Nearly","angle":0},
    {"time":29.29, "start":29.25,"team":"n", "scored":"Yi", "assist":"JC","angle":0},
    {"time":32.55, "team":"n", "scored":"Jason", "assist":"Stu","angle":0},
    {"time":35.21, "team":"b", "scored":"George", "assist":"Manzan","angle":2},
    {"time":36.20, "team":"b", "scored":"Gerald","angle":2},
    {"time":38.21, "team":"b", "scored":"David", "assist":"Manzan","angle":2},
    {"time": 40.11, "text": "Full Time","angle":2},
]

#44.49

create_highlight_clip("Game 1 Right.mp4",highlights1,non_bibs_team, bibs_team,cam2=gopro)
# Out:
# Moviepy - Building video Game 1 Right Highlights - 2026-03-27_v2.mp4.
# MoviePy - Writing audio in Game 1 Right Highlights - 2026-03-27_v2TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video Game 1 Right Highlights - 2026-03-27_v2.mp4
# Moviepy - Done !
# Moviepy - video ready Game 1 Right Highlights - 2026-03-27_v2.mp4
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
